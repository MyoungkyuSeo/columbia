# %%
#Part 1, Question 1 and 2
challenge_dict = {
                  "workouts" : {
                                "pushups" : 200,
                                "benchpress" : "5 sets of 10",
                                "squats" : "6 sets of 7",
                                "strictcurls" : "3 sets of 10"
                                    },
                  "wakeup" : 8,
                  "sleep" : "what is sleep",
                  "electives" : ["Ap Biology", "Ap European History", "Ap Environental Science", "Pre-Ap Computer Science"],
                  "coreclasses" : ("Pre-AP English II", "Pre-AP Chemistry", "AP World History", "Pre-AP Pre-Calculus")

                      }

# %%
#Part 1, Question 3
for x in challenge_dict:
  if challenge_dict[x] == "what is sleep":
    del challenge_dict[x]

print(challenge_dict)
# Out:
# {'workouts': {'pushups': 200, 'benchpress': '5 sets of 10', 'squats': '6 sets of 7', 'strictcurls': '3 sets of 10'}, 'wakeup': 8, 'electives': ['Ap Biology', 'Ap European History', 'Ap Environental Science', 'Pre-Ap Computer Science'], 'coreclasses': ('Pre-AP English II', 'Pre-AP Chemistry', 'AP World History', 'Pre-AP Pre-Calculus')}

# %%
#Part 1, Question 3
challenge_dict["wakeup"]
# Out:
# 8

# %%
#Part 1, Question 3
challenge_dict["workouts"]["pushups"]
# Out:
# 200

# %%
#Part 2
#Benefits of dictionaries I see are the ability to assign many key values and update them
#consistantly within one value. This simplifies many codes one have to do with lists and tuples. 
#It opens possibilities for games where there is a specific profile where datas are stored
