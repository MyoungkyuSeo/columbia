# %%
x = 29
y = "John Doe"

# %%
print(x)
# Out:
# 29

# %%
print(y)
# Out:
# John Doe

# %%
#Example 1
x = 21

# %%
x = 'Bobby'

# %%
print(x)
# Out:
# Bobby

# %%
#Variable Assignments
x = "Johnny Doey"
print(x)
x = 'Johnny Doey'
print(x)
# Out:
# Johnny Doey
# Johnny Doey

# %%
x = "Jonny middle name is 'Trevor'"
print(x)
# Out:
# Jonny middle name is 'Trevor'

# %%
#Multi Assigned
x, y, z = "Double Dark Chocolate", "Rocky Road", "Cheesecake"

# %%
print(x)
print(y)
print(z)
# Out:
# Double Dark Chocolate
# Rocky Road
# Cheesecake

# %%
#Multiple variables with same value
x = y = z = "Green Kale Salad"

print(x)
print(y)
print(z)
# Out:
# Green Kale Salad
# Green Kale Salad
# Green Kale Salad

# %%
#Print Statement
#Example with Print statements
x = "super interesting"

# %%
print("Python is " + x)
# Out:
# Python is super interesting

# %%
print("Python is",x)
# Out:
# Python is super interesting

# %%
print("Python is " + x + " " + x)
print("Python is", x, x )
# Out:
# Python is super interesting super interesting
# Python is super interesting super interesting

# %%
#Example 7
x = "Python is "
y = "super duper interesting"

# %%
#Create variable that combinse both
z = x + y

# %%
print(x)
# Out:
# Python is

# %%
print(y)
# Out:
# super duper interesting

# %%
print(z)
# Out:
# Python is super duper interesting

# %%
#Outputing variables and the + operator
#Example 8 
x = 40
y = 30

# %%
print(x + y)
# Out:
# 70

# %%
#Global Variables
#Example 10
x = "such a cool thing" #Local or Global?

# %%
#Create a Simple Function
def myfunc(): 
  print("Python is " + x)#Variable x is global

# %%
#Call Function
myfunc()
# Out:
# Python is such a cool thing

# %%
#Example 11
x = "spectacular" #global

# %%
#Create a Simple Function
def myfunc(): 
  #set a local variable
  x = "superduper" #local
  print("Python is " + x)#local

# %%
myfunc()
# Out:
# Python is superduper

# %%
print("Python is", x)
# Out:
# Python is spectacular

# %%
#Example 12
x = "BROING!"

# %%
def myfunc(): 
  #set x as a global variable
  global x
  x = "very NOT boring" #local

# %%
print("Python is", x)
# Out:
# Python is very NOT boring

# %%
#Call the function
myfunc()

# %%
print("Python is", x)
# Out:
# Python is very NOT boring

# %% [markdown]
# ## input variables

# %%
username = input("Enter Your Username: ")
# Out:
# Enter Your Username: Daniel Seo

# %%
print("How are we doing today? USER: " + username)
# Out:
# How are we doing today? USER: Daniel Seo
